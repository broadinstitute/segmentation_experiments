# %% [markdown]
# # Load Images

# %%
from functions.load_all_data import load_data_by_color

# def_img_objs, def_mask_colls, def_img_paths = load_data_by_color(color="Default")
# bw_img_objs, bw_mask_colls, bw_img_paths = load_data_by_color(color="Gray-Scales")
purple_img_objs, purple_mask_colls, purple_img_paths = load_data_by_color(color="Purple")
pink_img_objs, pink_mask_colls, pink_img_paths = load_data_by_color(color="Pink-Purple")

# %% [markdown]
# # Experiment with image cropping

# %%
from skimage import io
import numpy as np

# %%
sample = purple_img_objs[5]
io.imshow(sample)
sample.shape
# Out:
# (256, 320, 4)

# %%
cropped = sample[:64, :64, :]
io.imshow(cropped)
cropped.shape
# Out:
# (64, 64, 4)

# %%
row_start = np.random.randint(0, sample.shape[0] - 64)
col_start = np.random.randint(0, sample.shape[1] - 64)

row_end = row_start + 64
col_end = col_start + 64

rand_crop = sample[row_start:row_end, col_start:col_end, :]
io.imshow(rand_crop)

# %% [markdown]
# # Use functions import

# %%
from functions.crop_image import random_crop

sample = pink_img_objs[2]
func_crop_28 = random_crop(sample, crop_size=28, loud=True)
# Out:
# Original image size is 256 by 320. Crop starts at (207,113). Cropped image is 28x28 pixels

# %%
func_crop_64 = random_crop(sample, loud=True)
# Out:
# Original image size is 256 by 320. Crop starts at (20,226). Cropped image is 64x64 pixels

# %% [markdown]
# # Extend Cropping to Mask Composites

# %%
from functions.composites import composite_masks

sample = purple_img_objs[2]
composite = composite_masks(purple_mask_colls[2], loud=True)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
cropped_img, cropped_mask = random_crop(sample, composite, crop_size=(128,128), loud=True)
# Out:
# Original image size is 256 by 320. Crop starts at (13,56). Cropped image is 128x128 pixels
# Here is the crop of the corresponding mask composite

# %%
cropped_mask.any()
# function is robust, succeeds even when there is no nuclei in the image
# Out:
# True

# %%
cropped_img, cropped_mask = random_crop(sample, composite, loud=True)
# Out:
# Original image size is 256 by 320. Crop starts at (87,159). Cropped image is 64x64 pixels
# Here is the crop of the corresponding mask composite
